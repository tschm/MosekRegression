# %% [markdown]
# # Data import

# %%
import mosekTools.data.yahoo as datasource

# %%
import pandas
print pandas.__version__
# Out:
# 0.12.0

# %%
import datetime as dt

# %%
s = dt.datetime(2010, 1, 1)
e = dt.datetime(2012, 12, 31)
symbols = ["GS", "AAPL", "IBM", "GOOG", "T", "^GSPC"]
frame = datasource.get_data_yahoo(symbols=symbols, start=s, end=e)

# %%
frame.plot()
